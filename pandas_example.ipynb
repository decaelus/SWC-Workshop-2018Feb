# %% [markdown]
# From http://www.datacarpentry.org/python-ecology-lesson/01-starting-with-data/

# %%
import pandas as pd

# %%
# Note that pd.read_csv is used because we imported pandas as pd
pd.read_csv("data/surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
surveys_df = pd.read_csv("data/surveys.csv")
surveys_df.head()   # The head() function displays the first several lines of a file. It
                    # is discussed below.
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index([u'record_id', u'month', u'day', u'year', u'plot_id', u'species_id',
#        u'sex', u'hindfoot_length', u'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
plot_names = pd.unique(surveys_df['plot_id'])
print(plot_names)
# Out:
# [ 2  3  7  1  6  5  8  4 11 14 15 13  9 10 17 16 20 23 18 21 22 19 12 24]

# %%
print(len(plot_names))
print(surveys_df['plot_id'].nunique())
# Out:
# 24
# 24

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
# Group data by sex
grouped_data = surveys_df.groupby('sex')

# %%
# Summary statistics for all numeric columns by sex
grouped_data.describe()
# Out:
#          day                                                  hindfoot_length  \
#        count       mean       std  min  25%   50%   75%   max           count
# sex
# F    15690.0  16.007138  8.271144  1.0  9.0  16.0  23.0  31.0         14894.0
# M    17348.0  16.184286  8.199274  1.0  9.0  16.0  23.0  31.0         16476.0
#
#                  ...   weight            year                                 \
#           mean   ...      75%    max    count         mean       std     min
# sex              ...
# F    28.836780   ...     46.0  274.0  15690.0  1990.644997  7.598725  1977.0
# M    29.709578   ...     49.0  280.0  17348.0  1990.480401  7.403655  1977.0
#
#
#         25%     50%     75%     max
# sex
# F    1984.0  1990.0  1997.0  2002.0
# M    1984.0  1990.0  1997.0  2002.0
#
# [2 rows x 56 columns]

# %%
# Provide the mean for each numeric column by sex
grouped_data.mean()
# Out:
#         record_id     month        day         year    plot_id  \
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %%
grouped_data2 = surveys_df.groupby(['sex','plot_id'])
grouped_data2.describe()
# Out:
#                 day                                                     \
#               count       mean       std  min   25%   50%    75%   max
# sex plot_id
# F   1         848.0  15.338443  8.325993  1.0   9.0  15.0  22.00  31.0
#     2         970.0  16.288660  8.046509  1.0  10.0  16.0  23.00  31.0
#     3         893.0  16.161254  7.961706  1.0   9.0  16.0  23.00  31.0
#     4         872.0  15.746560  8.217829  1.0   9.0  16.0  22.00  31.0
#     5         527.0  15.722960  8.465716  1.0   9.0  16.0  23.00  31.0
#     6         737.0  16.313433  8.297017  1.0   9.0  16.0  23.00  31.0
#     7         335.0  15.313433  8.244412  1.0   9.0  14.0  22.50  31.0
#     8         840.0  15.836905  8.134936  1.0   9.0  16.0  22.00  31.0
#     9         853.0  15.555686  8.393954  1.0   9.0  15.0  22.00  31.0
#     10        141.0  16.964539  8.516716  1.0  10.0  17.0  24.00  31.0
#     11        822.0  16.283455  8.342322  1.0   9.0  16.0  23.00  31.0
# ...

# %%
grouped_data_by_plot = surveys_df.groupby(['plot_id'])
grouped_data_by_plot['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %%
# Count the number of samples by species
species_counts = surveys_df.groupby('species_id')['record_id'].count()
print(species_counts)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
surveys_df.groupby('species_id')['record_id'].count()['DO']

# %%
by_species_id = surveys_df.groupby('species_id')
by_species_id.describe()
# Out:
#                 day                                                        \
#               count       mean        std   min    25%   50%    75%   max
# species_id
# AB            303.0  15.788779   8.667608   1.0   8.50  15.0  22.50  31.0
# AH            437.0  16.427918   8.911772   1.0   9.00  16.0  25.00  31.0
# AS              2.0  15.500000  12.020815   7.0  11.25  15.5  19.75  24.0
# BA             46.0  12.826087   6.004829   4.0   8.00  13.0  15.75  26.0
# CB             50.0  18.920000   8.363770   1.0  12.25  17.5  26.75  31.0
# CM             13.0  10.000000   5.291503   7.0   7.00   8.0  11.00  26.0
# CQ             16.0  15.625000   7.982272   4.0  11.00  15.0  17.50  31.0
# CS              1.0   1.000000        NaN   1.0   1.00   1.0   1.00   1.0
# CT              1.0  23.000000        NaN  23.0  23.00  23.0  23.00  23.0
# CU              1.0  13.000000        NaN  13.0  13.00  13.0  13.00  13.0
# ...

# %%
# Make sure figures appear inline in Ipython Notebook
# %matplotlib inline
# Create a quick bar chart
species_counts.plot(kind='bar');

# %%
total_count = surveys_df.groupby('plot_id')['record_id'].nunique()
# Let's plot that too
total_count.plot(kind='bar');

# %%
men = surveys_df.groupby('plot_id').mean()
men['weight'].plot(kind='bar')

# %%
by_sex = surveys_df.groupby('sex')
by_sex.describe()
# Out:
#          day                                                  hindfoot_length  \
#        count       mean       std  min  25%   50%   75%   max           count
# sex
# F    15690.0  16.007138  8.271144  1.0  9.0  16.0  23.0  31.0         14894.0
# M    17348.0  16.184286  8.199274  1.0  9.0  16.0  23.0  31.0         16476.0
#
#                  ...   weight            year                                 \
#           mean   ...      75%    max    count         mean       std     min
# sex              ...
# F    28.836780   ...     46.0  274.0  15690.0  1990.644997  7.598725  1977.0
# M    29.709578   ...     49.0  280.0  17348.0  1990.480401  7.403655  1977.0
#
#
#         25%     50%     75%     max
# sex
# F    1984.0  1990.0  1997.0  2002.0
# M    1984.0  1990.0  1997.0  2002.0
#
# [2 rows x 56 columns]

# %%
by_sex['day'].count().plot(kind='bar')

# %%
by_plot_sex = surveys_df.groupby(['plot_id','sex'])
plot_sex_count = by_plot_sex['weight'].sum()
spc = plot_sex_count.unstack()
s_plot = spc.plot(kind='bar',stacked=True,title="Total weight by plot and sex")
s_plot.set_ylabel("Weight")
s_plot.set_xlabel("Plot")
